# %% [markdown]
# 머신러닝의 파라미터는 계쑤
#
# 파라미터 > 모델이 스스로 학습해서 도출해낸 계수
#
# positive 안쓰는게 나아~
#
#
# 리스트를 원소로갖는딕셔너리로 하이퍼파라미터의 조합을 생성
# > 이거f gridsearchcv 에 던졎면 굿
# >
# > 과적합 판정은 에러를 기준으로하는것

# %% [markdown]
# # [LAB 06] 지도학습 > 예측 > 선형 > 05-하이퍼 파라미터 튜닝
#
# ## #01.하이퍼 파라미터 튜닝 개요
# ### [1] 파라미터와 하이퍼 파라미터의 차이
# - 머신러닝 모델을 만들 때 설정되는 값은 크게 두 종류
# - 파라미터와 하이퍼파라미터를 구별해야 튜닝의 개념을 이해하기 좋음
#
# #### (1) 파라미터
# - 모델이 데이터를 기반으로 스스로 학습하여 도출해낸 값
# - 사용자가 지정한 값이 아님
# - 학습 과정에서 자동으로 계산됨
#
#
# | 항목 | 설명 |
# |---|---|
# | 누가 정함 | 모델이 데이터로부터 자동 추정 |
# | 언제 정해짐 | 학습(fit) 과정 중 |
# | 역할 | 입력과 출력 간의 관계를 수식으로 표현 |
# | 예시 | 선형회귀의 회귀계수 β, 절편(intercept) |
#
# ### ✏️ 예시 설명
# - 집 크기와 가격 데이터를 넣으면
# - **“면적이 1 증가할 때 가격이 얼마나 증가하는가”**를
# - **모델이 스스로 계산함**
# - 이때 계산된 숫자 (계수) 가 **파라미터(parameter)**임
#
#
# #### (2) 하이퍼 파라미터
# - 모델이 학습하기 전에 사람이 미리 정해준 값
# - 학습방식이나 조건을 조절하는 설정값
#
# | 항목 | 설명 |
# |---|---|
# | 누가 정함 | 사용자 |
# | 언제 정해짐 | 학습 시작 이전 |
# | 역할 | 학습 규칙, 방식 통제 |
#
# - 예시
# `fit_intercept`, `positive`, `cv`
#
# - ✏️ 예시 설명
# - “절편을 사용할 것인가?”
# - “계수를 양수로만 제한할 것인가?”
# → 이런 질문에 대한 **사전 설정값**

# %% [markdown]
# ### [2] 하이퍼 파라미터 튜닝 개념
# #### (1) 튜닝의 기본 개념
# - 하이퍼 파라미터는 하나의 정답이 정해져 있는게 아님
# - 여러 후보 중에서 특정 단게를 통해 검증 성능이 가장 좋은 설정으로 선택하는 과정이 필요함
#
#
# 1. 하이퍼파라미터 후보 여러 개 준비
# 2. 각 조합으로 모델 학습
# 3. 검증 데이터로 성능 비교
# 4. 가장 성능이 좋은 조합 선택
#
#
# #### (2) 튜닝의 목적
#
# ### (2) 튜닝의 목적
#
# - **성능 개선**
#   - 예측 오차를 줄이기 위함
# - **과적합 방지**
#   - 데이터에 과도하게 맞춰지는 것 방지
# - **모델 선택 근거**
#   - 왜 이 설정을 썼는지 설명 가능
#
# > 선형회귀는 단순한 모델이기 때문에 튜닝할 만한 하이퍼파라미터가 거의 없음.
# > 여기서는 튜닝의 개념과 방법을 익히기 위해 가장 단순한 선형회귀를 사용함.
# > 선형회귀에서는 하이퍼파라미터 튜닝을 통한 성능 향상은 **기대하기 어려움**.

# %% [markdown]
# ### [3] 튜닝의 형식적 의미와 실질적 효과 구분
# - 머신러닝 실무,보고서에서 튜닝을 했다는 말의 의미
#
# #### (1) 형식적 의미의 튜닝
#
# | 항목 | 설명 |
# |---|---|
# | GridSearchCV 사용 | 자동 탐색 절차 적용 |
# | 최적 파라미터 도출 | `best_params_` 존재 |
# | 보고서 작성 가능 | 절차 수행 근거 확보 |
#
# #### (2) 실질적 효과로서의 튜닝
# | 항목 | 설명 |
# |---|---|
# | 성능 개선 여부 | R², MAE 등이 실제로 좋아졌는가 |
# | 개선 폭 | 변화가 의미 있는 수준인가 |
# | 해석 가능성 | 왜 좋아졌는지 설명 가능한가 |

# %% [markdown]
# ## #02.LinearRegression 의 하이퍼 파라미터 요약
# ### [1] LinearRegression 튜닝 가능 항목 한눈에 보기
#
# | 하이퍼파라미터 | 기본값 | 성능 영향 | 핵심 요약 |
# |---|---|---|---|
# | fit_intercept | True | 있음 | 유일하게 의미 있는 튜닝 대상 |
# | copy_X | True | 없음 | 성능과 무관 |
# | positive | False | 매우 제한적 | 특수 목적용 |
# | n_jobs | None | 없음 | 속도 옵션 |
#
#
# ### [2] 핵심 파라미터 fit_intercept
# - 회귀식에 절편을 포함할지 여부 결정
# - 기본값 True 가 일반적
#
# | 설정 | 의미 |
# |---|---|
# | True | 절편 포함 |
# | False | 원점을 지나는 직선 |
#
# #### 👉 언제 False를 쓸까?
# - 모든 변수 평균이 0
# - 이론적으로 원점 통과가 명확한 경우
#
#
# ### [3] 거의 튜닝하지 않는 파라미터들
#
# 1. **copy_X**
#    - 입력 데이터 복사 여부
#    - 성능과 무관
#
# 2. **positive**
#    - 모든 계수를 양수로 제한
#    - 해석 목적 외에는 거의 사용 안 함
#
# 3. **n_jobs**
#    - CPU 사용 개수
#    - 결과에는 영향 없음
#    - `-1` 지정 시 모든 코어 사용

# %% [markdown]
# ## #03. 하이퍼파라미터 탐색
#
# ### [1] 왜 탐색 방식이 필요한가?
# 하이퍼 파라미터는 데이터가 바뀌면 최적값이 달라짐
# 즉 사람이 하나씩 정하는 방식에는 한계 존재
#
#
# | 문제 | 설명 |
# |---|---|
# | 경우의 수 증가 | 파라미터 조합이 빠르게 늘어남 |
# | 주관 개입 | 임의 설정 위험 |
# | 재현성 부족 | 동일 결과 보장 어려움 |
#
#
# ### [2] 수동 탐색
#
# - 사용자가 직접 값을 정함
# - 하이퍼파라미터 조합에 대해 여러 번 학습 반복
#
# 👉 초보자 연습용으로는 가능
# 👉 실무·수업에서는 **비효율적**
#
#
#
# ### [3] 자동 탐색
# - 정해진 규칙에 따라 모든 후보를 동일 조건에서 비교
#
#
# ### [4] GridSearchCV
#
#
# - 하이퍼파라미터 후보값을 **격자(grid)** 형태로 나열
# - 모든 조합을 **교차검증**으로 평가
# - 가장 성능이 좋은 조합 선택
#
# | 단계 | 설명 |
# |---|---|
# | 1 | 파라미터 후보 목록 생성 |
# | 2 | 각 조합으로 모델 학습 |
# | 3 | 교차검증 점수 계산 |
# | 4 | 최고 성능 조합 선택 |
#
#
# #### GridSearchCV 구성 요소
#
# | 구성 요소 | 역할 |
# |---|---|
# | estimator | 사용 모델 |
# | param_grid | 파라미터 후보 |
# | cv | 교차검증 분할 수 |
# | scoring | 평가 기준 |

# %% [markdown]
# ## #04.준비작업
# ### [1] 패키지 참조

# %%
from hossam import *
from pandas import DataFrame, read_excel
from matplotlib import pyplot as plt
import seaborn as sb
import numpy as np
import statsmodels as sm

from itertools import combinations

#데이터 표준화 모듈
from sklearn.preprocessing import StandardScaler

#선형 회귀 분석 모듈
from sklearn.linear_model import LinearRegression

#훈련/검증 데이터 분리 모듈
from sklearn.model_selection import KFold,cross_val_predict,learning_curve,train_test_split,GridSearchCV

from scipy.stats import pearsonr,spearmanr


#성능 평가 지표 모듈
from sklearn.metrics import(
  r2_score,
  mean_absolute_error,
  mean_squared_error,
  mean_absolute_percentage_error
)

# %% [markdown]
# ### [2] 데이터 가져오기

# %%
origin = load_data('fish_processed')
origin.head()
# Out:
# 농어의 길이,높이,두께,무게를 조사한 데이터의 전처리 버전
#          길이        높이        두께        무게
# 0 -2.180225 -2.016507 -1.896175  1.931521
# 1 -1.587434 -1.518703 -1.560774  3.496508
# 2 -1.442032 -1.417039 -1.316328  3.713572
# 3 -1.307815 -1.147103 -1.202633  3.960813
# 4 -1.173599 -1.147103 -1.026405  4.262680

# %% [markdown]
# ### [3] 데이터 분할

# %%
yname = '무게'
x=origin.drop(columns=[yname])

y=origin[yname]

x_train,x_test,y_train,y_test = train_test_split(
  x,y,test_size=0.25,random_state=52
)

x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((42, 3), (14, 3), (42,), (14,))

# %% [markdown]
# ## #05.하이퍼 파라미터 튜닝을 적용한 머신러닝
# ### [1] 모델구축

# %%
#고정 파라미터는 모델 객체 생성시 설정
model = LinearRegression(n_jobs=-1)

#탐색할 하이퍼 파라미터 그리드 설정
param_grid = {'fit_intercept':[True,False],'positive':[True,False]}

#그리드 서치 객체 생성 > 자동으로 여러 하이퍼 파라미터 조합을 테스트 해줌
gs = GridSearchCV(estimator = model , param_grid=param_grid , cv=5,scoring = 'r2')


gs.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(n_jobs=-1),
#              param_grid={'fit_intercept': [True, False],
#                          'positive': [True, False]},
#              scoring='r2')

# %% [markdown]
# ### [2] 결과 확인
# #### (1) 최적 모형

# %%
best_model=gs.best_estimator_
display(best_model)
# Out:
# LinearRegression(n_jobs=-1, positive=True)

# %% [markdown]
# #### (2) 최적 파라미터
# - 가장 점수가 높았던 설정

# %%
gs.best_params_
# Out:
# {'fit_intercept': True, 'positive': True}

# %% [markdown]
# #### (3) 최고 성능 점수
# - 교차검증 평균 R2

# %%
gs.best_score_
# Out:
# np.float64(0.9208159625330845)

# %% [markdown]
# ### [3] 과적합 판정
