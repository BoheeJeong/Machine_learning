# %% [markdown]
# 다중분류 성능 평가에선s r2 제외
#
#
# roc_auc 대신 accuracy, f1 이 무난
#
# OvR
#
# ZERO_DIVISION -> 0 예외처리
#
# OvO
# OvR : 하나와 나머지를 비교
# 0 VS 1,2
# 1 VS 0,2
# 2 VS 0,1

# %% [markdown]
# # [LAB 09] 지도학습 > 분류 > 07-다중분류(1)
# - 종속변수의 값 종류가 3개 이상인 경우

# %% [markdown]
# ## #01.준비작업
# ### [1] 패키지 가져오기
