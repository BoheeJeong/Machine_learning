# %% [markdown]
# 우리가 분류모형에서..
# 평균절대오차는 절대값이라서 방향을 논할 수 없으니
#
#
# 제곱해서 평균제곱오차를 구하고
#
# 이게 너무 크니까 루트로 rmse 를 구한다고 말했고
# 이게rmse 에러율로 보자고 했었죠?
#
#
# 평균 오차는 결국 평균 절대오차에서 기반한 것
#
# 예를 들어서 매출액 예측할 때
# 실제 머신러닝이 예측한 값과 실제 매출액 값에 오차가 정확하게 나오는거지
#
#
#
# 절대값으로...
#
#
#
# 근데 절대수치가 아니라 비율로 판정해야할 떄도 있겠지?
# 이런 비율적인 계산을 해야할떄는 RMSLE 라는 값이 따로 있음 로그 씌워서
#
#
#
# mean_squared_log_error(y실제값,추정치)
# msle (제곱된거)
#
#
# 이거를 루트 씌우면~

# %% [markdown]
# np.sqrt(mean_squared_log_error(y실제값,추정치)) = rmsle
#
#
#
# 평가지표로 요새 이 값으로 보는 경우도 좀 많음 .....
#
#
# 이 평가지표도 같이 추가해보면 좋을듯
